# %% [markdown]
# # Taller en clase #1
# Generando numeros aleatorios en ptython.
# Objetivos:
# 1. Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# 2. Usar las herramientas de python de manejo de arreglos.
# 3. Usar las herramientas de generación de gráficas de python.
# ## Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=3000
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew , kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %% [markdown]
# ## Primer punto Binomial

# %%
#binomial con cierto p entre 0 y 1 y cierto n
n,p = 10, 0.5
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
r = binom.rvs(n, p, size=N)

# %%
  plt.plot(r)
  plt.title(str(N)+" puntos distribuidos binomial con p="+str(p))
  plt.show()

# %%
    r.sort()
    plt.plot(r)
    plt.title(str(N)+" puntos distribuidos binomial ordenados con p="+str(p))
    plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.5 son u_est= 4.99879 var_est= 2.4781285359

# %% [markdown]
# ## Primer punto Geometrica

# %%
# Geométrica con cierto p entre 0 y 1
p = 0.3
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
r = geom.rvs(p, size=N)

# %%
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Geometricamente con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Geometricamente con p="+str(p))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Geometrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Geometrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la Geometrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la Geometrica con p= 0.3 son u_est= 3.32064 var_est= 7.647549990399999

# %% [markdown]
# ## Primer punto Poisson

# %%
# Poisson con cierto Lamnda L
L = 5
from scipy.stats import poisson
mu=L
mean, var, skew, kurt = poisson.stats(mu, moments='mvsk')
r = poisson.rvs(mu, size=N)

# %%
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson")
plt.show()

# %%
 r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson")
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Poisson")
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza poisson u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para poisson","son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza poisson u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para poisson son u_est= 4.98925 var_est= 4.983614437500001

# %% [markdown]
# ## Primer Punto Binomial Negativa

# %%
#Binomial negativa con parametro p después de r fallos
r,p = 5,0.5
from scipy.stats import nbinom
n=r;
mean, var, skew, kurt = nbinom.stats(n, p, moments='mvsk')

# %%
r = nbinom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomialmente negativo con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomialmente negativo  ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomialmente negativo  con p="+str(p))
plt.show()
print("r es de tipo " + str(type(r)))
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial negativa con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# r es de tipo <class 'numpy.ndarray'>
# Los valores teoricos de la media y varianza para la binomial negativa con p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la binomial negativa con p= 0.5 son u_est= 4.99644 var_est= 10.0377673264

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=10000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.971391002002103 var_est= 0.2653971302092896

# %% [markdown]
# ## Segundo punto uniforme

# %%
# Uniforme entre 0 y 255
a=0
b=255
mean, var, skew, kurt = scipy.stats.uniform.stats(moments='mvsk',loc=a,scale=b)
r = scipy.stats.uniform.rvs(loc=a,scale=b,size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos" )
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos" )
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos " )
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 127.5 var= 5418.75
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 127.51712211634656 var_est= 5418.255057011344

# %% [markdown]
# ## Segundo punto Exponencial

# %%
# Exponencial con Lamnda L
L=0.3
mean, var, skew, kurt = scipy.stats.expon.stats(L,moments='mvsk')
r = scipy.stats.expon.rvs (L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales")
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 1.3 var= 1.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.3000487682699167 var_est= 0.9986802888383058

# %% [markdown]
# ## Segundo punto Chi cuadrada

# %%
#Chi cuadrada con K grados de libertad
K=3.0
mean, var, skew, kurt = scipy.stats.chi2.stats(K,moments='mvsk')
r = scipy.stats.chi2.rvs (K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales")
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 2.9678234181040795 var_est= 5.616968333957857

# %% [markdown]
# ## Segundo punto Gamna

# %%
#Gamma con parametros k y theta t
k,t=2.54,0.43
mean, var, skew, kurt = scipy.stats.gamma.stats(a=k,scale=t,moments='mvsk')
r = scipy.stats.gamma.rvs (a=k,scale=t,size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales")
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para son u= 1.0922 var= 0.469646
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 1.0972784942035017 var_est= 0.46851614293350696
